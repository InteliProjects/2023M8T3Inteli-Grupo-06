# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:/Users/Inteli/Downloads/Data Base Full.xlsx')

# %%
df = df.drop("Unnamed: 0", axis = 1)

# %%
df.head()
# Out:
#              Supplier Name Normalized Supplier Name      Parent Supplier Name  \
# 0  1ST AVE MACHINE USA INC  1ST AVE MACHINE USA INC  1st Ave Machine USA Inc.
# 1  1ST AVE MACHINE USA INC  1ST AVE MACHINE USA INC  1st Ave Machine USA Inc.
# 2  1ST AVE MACHINE USA INC  1ST AVE MACHINE USA INC  1st Ave Machine USA Inc.
# 3  1ST AVE MACHINE USA INC  1ST AVE MACHINE USA INC  1st Ave Machine USA Inc.
# 4  1ST AVE MACHINE USA INC  1ST AVE MACHINE USA INC  1st Ave Machine USA Inc.
#
#   Region Requestor Name      Preparer Name                    Level 1  \
# 0  NORAM            NaN                NaN  Sales, Marketing & Events
# 1  NORAM     Cara Brann   Jessica Shimshak  Sales, Marketing & Events
# 2  NORAM    Chloe Kwock      Nicole Franco  Sales, Marketing & Events
# 3  NORAM    Chloe Kwock  Princess Costello  Sales, Marketing & Events
# 4  NORAM    Jess Jabbar  Princess Costello  Sales, Marketing & Events
#
#             Level 2           Level 3              Business Unit  ...  \
# ...

# %%
df.columns
# Out:
# Index(['Supplier Name', 'Normalized Supplier Name', 'Parent Supplier Name',
#        'Region', 'Requestor Name', 'Preparer Name', 'Level 1', 'Level 2',
#        'Level 3', 'Business Unit', 'Legal Entity', 'Cost Center',
#        'Cost Center (Base Level)', 'Cost Center (Level 4)',
#        'Cost Center (Level 5)', 'Cost Center (Level 6)', 'GL Desc (Level 4)',
#        'GL Desc (Level 5)', 'GL Desc (Level 6)', 'Invoice ID',
#        'Invoice Number', 'Invoice Source', 'Month, Day, Year of Payment Date',
#        'PO Number', 'Amount (USD)'],
#       dtype='object')

# %%
round(df['Amount (USD)'].mean(),3)
# Out:
# 42123.3
